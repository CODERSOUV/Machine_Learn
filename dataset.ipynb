# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv('airfoil.dat',sep='\t',header=None)

# %%
dataset
# Out:
#          0     1       2     3         4        5
# 0      800   0.0  0.3048  71.3  0.002663  126.201
# 1     1000   0.0  0.3048  71.3  0.002663  125.201
# 2     1250   0.0  0.3048  71.3  0.002663  125.951
# 3     1600   0.0  0.3048  71.3  0.002663  127.591
# 4     2000   0.0  0.3048  71.3  0.002663  127.461
# ...    ...   ...     ...   ...       ...      ...
# 1498  2500  15.6  0.1016  39.6  0.052849  110.264
# 1499  3150  15.6  0.1016  39.6  0.052849  109.254
# 1500  4000  15.6  0.1016  39.6  0.052849  106.604
# 1501  5000  15.6  0.1016  39.6  0.052849  106.224
# 1502  6300  15.6  0.1016  39.6  0.052849  104.204
#
# [1503 rows x 6 columns]

# %%
dataset.columns=['frequency','attack-angle','chord-length','free-stream-velocity','suction-side-displacement-thickness','scaled-sound-pressure']

# %%
dataset
# Out:
#       frequency  attack-angle  chord-length  free-stream-velocity  \
# 0           800           0.0        0.3048                  71.3
# 1          1000           0.0        0.3048                  71.3
# 2          1250           0.0        0.3048                  71.3
# 3          1600           0.0        0.3048                  71.3
# 4          2000           0.0        0.3048                  71.3
# ...         ...           ...           ...                   ...
# 1498       2500          15.6        0.1016                  39.6
# 1499       3150          15.6        0.1016                  39.6
# 1500       4000          15.6        0.1016                  39.6
# 1501       5000          15.6        0.1016                  39.6
# 1502       6300          15.6        0.1016                  39.6
#
#       suction-side-displacement-thickness  scaled-sound-pressure
# 0                                0.002663                126.201
# ...

# %%
dataset.corr()
# Out:
#                                      frequency  attack-angle  chord-length  \
# frequency                             1.000000     -0.272765     -0.003661
# attack-angle                         -0.272765      1.000000     -0.504868
# chord-length                         -0.003661     -0.504868      1.000000
# free-stream-velocity                  0.133664      0.058760      0.003787
# suction-side-displacement-thickness  -0.230107      0.753394     -0.220842
# scaled-sound-pressure                -0.390711     -0.156108     -0.236162
#
#                                      free-stream-velocity  \
# frequency                                        0.133664
# attack-angle                                     0.058760
# chord-length                                     0.003787
# free-stream-velocity                             1.000000
# suction-side-displacement-thickness             -0.003974
# scaled-sound-pressure                            0.125103
#
# ...

# %%
dataset.isnull().sum()
# Out:
# frequency                              0
# attack-angle                           0
# chord-length                           0
# free-stream-velocity                   0
# suction-side-displacement-thickness    0
# scaled-sound-pressure                  0
# dtype: int64

# %%
X=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train
# Out:
#       frequency  attack-angle  chord-length  free-stream-velocity  \
# 845         500          11.2        0.0508                  71.3
# 1026      10000           4.8        0.0254                  55.5
# 621        2000           7.2        0.1524                  39.6
# 1371        630           6.7        0.1016                  31.7
# 195        6300           0.0        0.2286                  71.3
# ...         ...           ...           ...                   ...
# 1130        250          12.7        0.0254                  39.6
# 1294        800           3.3        0.1016                  71.3
# 860         630          11.2        0.0508                  39.6
# 1459        315          12.3        0.1016                  31.7
# 1126       5000          12.7        0.0254                  71.3
#
#       suction-side-displacement-thickness
# 845                              0.014072
# 1026                             0.000873
# 621                              0.009092
# ...

# %%
import seaborn as sns
sns.pairplot(dataset,hue='suction-side-displacement-thickness')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/seaborn/_oldcore.py:1075: FutureWarning:
#
# ...

# %%
for i in X_train.columns:
    sns.boxplot(X_train[i])

# %%
sns.scatterplot(x=X_train['frequency'],y=y_train)
# Out:
# <Axes: xlabel='frequency', ylabel='scaled-sound-pressure'>

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.linear_model import LinearRegression
Linear
from sklearn.model_selection import cross_val_score
mse=cross_val_score(regressor,X_train,y_train,cv=5,scoring='neg_mean_absolute_error')
np.mean(mse)
# Out:
#   Cell In[154], line 1
#     from sklearn.
#                  ^
# SyntaxError: invalid syntax

# %%
y_pred=regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.5124474986138434

# %%
df=sns.load_dataset('iris')

# %%
import plotly as py
from plotly.offline import iplot
import plotly.tools as tls
import cufflinks as cf
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
cf.set_config_file(theme="solar")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.30.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df.iplot(kind='box')
